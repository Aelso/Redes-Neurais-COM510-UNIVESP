# %% [markdown]
# ## [**Semana 1 - Atividade Avaliativa**](https://ava.univesp.br/ultra/courses/_8361_1/cl/outline)

# %% [markdown]
# **PERGUNTA 1**
#
# Sobre as redes neurais é correto afirmar:
#
# 1. Assim como os processadores tradicionais (CPU), as redes neurais são caracterizadas por apresentar um processamento serial.
# 2. O conhecimento da rede neural é adquirido a partir de um processo de interação com o ambiente (dados), denominado processo de aprendizagem ou treinamento.
# 3. Embora possuam grande capacidade computacional, as redes neurais possuem limitações ao tratar dados não-lineares.
#
# Assinale a alternativa correta:
#
# As afirmações i e iii estão corretas.
#
# Apenas a afirmação iii está correta.
#
# Todas as afirmações estão corretas.
#
# As afirmações i e ii estão corretas.
#
# **Apenas a afirmação ii está correta.** 🚂

# %% [markdown]
# **Comentário da resposta:**
# Apenas a afirmação ii está correta (ver página 28 livro do Simon Haykin). As demais afirmações estão incorretas, pois: i. as redes neurais são sistemas computacionais maciçamente paralelos e não seriais e iii. As redes neurais são capazes de mapear (aprender) relações não lineares (Seção 1.1 do Livro do Simon Haykin)

# %% [markdown]
# **PERGUNTA 2**
#
# Sobre o paradigma de aprendizagem não-supervisionado, é correto afirmar:
#
# Como os dados de treinamento consistem em exemplos não-rotulados, a técnica de correção de erros não pode ser adotada no treinamento não-supervisionado.
#
# A classificação de dados e a regressão são tarefas comuns do paradigma não-supervisionado.
#
# **O agrupamento de dados e a detecção de anomalias são tarefas comuns do paradigma não-supervisionado.** 🍯
#
# Bases de dados rotuladas não podem ser usadas para desenvolvimento de modelos não-supervisionados.
#
# Redes não-supervisionadas podem ser treinadas apenas com a técnica de aprendizagem competitiva.

# %% [markdown]
# **Comentário da resposta:**
# O aprendizado não-supervisionado demanda uma base de dados não-rotulada. Embora, bases rotuladas possam ser usadas desconsiderando seus respectivos rótulos. As tarefas de agrupamento de dados (clustering), detecção de anomalias e redução de dimensionalidade são tarefas comuns deste paradigma. Diversas técnicas de aprendizagem podem ser consideradas neste paradigma, como a aprendizagem competitiva, Hebbiana e Boltzmann. A própria técnica de correção de erros pode ser considerada neste paradigma, por exemplo no treinamento de autoencoders.

# %% [markdown]
# **PERGUNTA 3**🤟
#
# O neurônio artificial representa a unidade de processamento em uma rede neural. Sua modelagem matemática tem como base a estrutura e funcionamento do neurônio biológico. Considerando os elementos básicos do neurônio artificial e o seu funcionamento, é correto afirmar que:
#
# o neurônio artificial utilizado em redes neurais consiste numa modelagem matemática quantitativa do neurônio biológico.
#
# **a função de ativação tem como objetivo restringir a amplitude de saída do neurônio artificial e pode assumir diversas formas, lineares e não-lineares.** 🏆
#
# o corpo celular do neurônio matemático é representado por um combinador não-linear das entradas e seus respectivos pesos.
#
# os pesos dos neurônios artificiais podem assumir apenas valores positivos, representando a presença ou ausência de sinais de entrada.
#
# o neurônio artificial é modelado a partir de um processo determinístico, ou seja, para uma mesma entrada, ele sempre responderá da mesma forma.

# %% [markdown]
# **Comentário da resposta:**
# O neurônio é composto por três partes fundamentais: as sinapses, o somador (corpo celular) e a função de ativação. A função de ativação, por sua vez, é responsável por modular a saída do neurônio. As demais alternativas estão erradas, pois: 1) a modelagem do neurônio artificial é uma abordagem qualitativa e bastante simplificada quando o comparamos com o modelo biológico. De qualquer forma, cabe ressaltar que há modelos quantitativos de neurônio matemáticos, como o Modelo Hodgkin-Huxley, amplamente utilizado em neurociência computacional; 2) as sinapses podem assumir tanto valores positivos quanto negativos; 3) o corpo celular é normalmente representado por um combinador linear das entradas e pesos; e 4) há neurônios artificiais determinísticos e estocásticos.

# %% [markdown]
# **PERGUNTA 4**
#
# O treinamento de uma rede neural consiste na alteração dos pesos (parâmetros livres) da rede a partir de um processo de estímulo pelo ambiente (dados). Considerando a regra de aprendizagem por correção de erros, podemos afirmar:
#
# Os pesos são corrigidos a partir da correlação calculada entre o sinal de entrada e o sinal de saída do neurônio.
#
# **Um sinal de erro, utilizado no treinamento, é gerado a partir da comparação da saída da rede com a resposta desejada.**🐆
#
# Após calcular o erro, apenas o neurônio vencedor possui seus pesos atualizados.
#
# A taxa de aprendizagem não demanda ajustes nesta forma de treinamento.
#
# Os passos de atualização são sempre constantes e dependem apenas do sinal do erro calculado. Quando o erro é positivo, o peso do neurônio é reduzido, caso contrário ele é aumentado.

# %% [markdown]
# **Comentário da resposta:**
# A aprendizagem por correção de erro consiste em gerar um sinal de erro calculado a partir da saída fornecida pela rede neural e a resposta desejada para o padrão fornecido. Este erro é utilizado para o cálculo da correção dos pesos. O processo tem por objetivo reduzir, iterativamente, o erro apresentado pela rede.

# %% [markdown]
# ## **Semana 2 - Atividade Avaliativa**

# %% [markdown]
# **PERGUNTA 1**
#
# Considerando a representação da arquitetura de uma rede neural como um grafo, é correto afirmar:
#
# 1. É possível representar o fluxo do sinal a partir desta representação.
# 2. Grafos podem representar apenas redes de neurônios lineares.
# 3. Elos sinápticos representam relações lineares entre a entrada e peso produzindo a saída do elo.
# 4. Elos de ativação representam funções de ativação lineares.
# 5. O grafo permite tanto a representação de sinais intra- quanto inter-neurônios.
#
# Assinale a alternativa correta:
#
# Todas as afirmações estão corretas.
#
# Apenas as afirmações iii, iv e v estão corretas.
#
# Apenas as afirmações ii, iii e v estão corretas.
#
# **Apenas as afirmações i, iii e v estão corretas.** ♟
#
# Apenas as afirmações i e iii estão corretas.

# %% [markdown]
# **Comentário da resposta:**
# Os grafos orientados permitem representar tantos aspectos internos (intra) quanto externos (inter) dos neurônios. As afirmações ii e iv estão erradas, pois o grafo e o elo de ativação podem representar sinais não-lineares

# %% [markdown]
# **PERGUNTA 2**
#
# Identifique as arquiteturas de redes neurais associadas aos grafos abaixo:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Assinale a alternativa correta:
#
# i) rede alimentada adiante com camada única; ii) rede recorrente sem autoalimentação; iii) rede recorrente com neurônios ocultos; iv) rede alimentada adiante com múltiplas camadas.
#
# **i) rede recorrente sem autoalimentação; ii) rede alimentada adiante com camada única; iii) rede recorrente com neurônios ocultos; iv) rede alimentada adiante com múltiplas camadas.** ♎
#
# i) rede alimentada adiante com camada única; ii) rede recorrente sem autoalimentação; iii) rede alimentada adiante com múltiplas camadas; iv) rede recorrente com neurônios ocultos.
#
# i) rede recorrente com neurônios ocultos; ii) rede alimentada adiante com camada única; iii) rede recorrente sem autoalimentação; iv) rede alimentada adiante com múltiplas camadas.
#
# i) rede recorrente sem autoalimentação; ii) rede alimentada adiante com camada única; iii) rede alimentada adiante com múltiplas camadas; iv) rede recorrente com neurônios ocultos.

# %% [markdown]
# **Comentário da resposta:**
# As imagens representam, respectivamente: i) uma rede recorrente sem autoalimentação; ii) uma rede alimentada adiante com camada única; iii) uma rede recorrente com unidades ocultas e iv) uma rede alimentada adiante com múltiplas camadas (2 camadas: uma camada oculta e uma camada de saída).

# %% [markdown]
# **PERGUNTA 3**
#
# Considerando as entradas {x1, x2} definidas a seguir: ({0;0}, {0;1}, {1;0}, {1;1}). Qual é a função lógica representada por cada Perceptron abaixo?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3 imagens em preto com fundo branco (1, 2 e 3) apresentam a representação de um neurônio com duas entradas x1 e x2 e um termo de bias. Cada entrada está associada a um peso, x1 está associada ao peso w1 e x2 associada ao peso w2. A saída dos neurônios é representada por y. No caso 1), os pesos assumem os seguintes valores: w1 = 0,3; w2=0,3 e o bias -0,4. No caso 2), os pesos assumem os valores w1=0,5; w2=0,5 e bias =-0,2. Por fim, no caso 3), w1=1,0; w2=1,0 e o bias = -1,5.
#
# Assinale a alternativa correta:
#
# 1– Porta OR, 2 – Porta OR; 3 – Porta AND
#
# 1– Porta AND, 2 – Porta AND; 3 – Porta AND
#
# 1– Porta OR, 2 – Porta AND; 3 – Porta OR
#
# 1– Porta AND, 2 – Porta OR; 3 – Porta OR
#
# **1– Porta AND, 2 – Porta OR; 3 – Porta AND** ✌

# %% [markdown]
# **Comentário da resposta:**
# Nos exemplos acima, a saída do neurônio Perceptron é calculada da seguinte forma:
#
# y=1 se : $x_1w_1 + x_2w_2 + BIAS > 0$ e $y=0$ caso contrário. Nos exemplos, [1] e [3], a inequação será satisfeita apenas quando os valores de x1=1 e  x2=1, ou seja, portas AND. No exemplo 2, basta uma das entradas igual a 1 para que a inequação seja satisfeita, ou seja, uma porta OR.

# %% [markdown]
# **PERGUNTA 4**
#
# O conjunto de dados é comumente dividido em três subconjuntos: treino, validação e teste. Sobre cada subconjunto é correto afirmar:
# 1. O conjunto de treino é utilizado para ajustar os parâmetros do modelo, i.e., pesos.
# 2. O conjunto de validação é utilizado para avaliar a capacidade de generalização dos modelos e, como consequência, auxiliar na seleção do melhor conjunto de hiperparâmetros.
# 3. O conjunto de teste é usado para aferir a acurácia final do modelo gerado.
# 4. Todos os subconjuntos devem vir da mesma distribuição de dados.
#
# **Assinale a alternativa correta:**
#
# Apenas as alternativas ii, iii e iv estão corretas. ❎
#
# Apenas as alternativas i e iii estão corretas.
#
# Nenhuma das alternativas está correta.
#
# Apenas as alternativas i e ii estão corretas.
#
# **Todas as alternativas estão corretas.** 🌊

# %% [markdown]
# **Comentário da resposta:**
# O desenvolvimento de um modelo de aprendizado de máquina, como uma rede neural, demanda ajuste de parâmetros (pesos) e hiperparâmetros (número de camadas, número de neurônios etc.). Para desenvolvimento dos modelos, tradicionalmente dividimos o conjunto disponível em 3 partes: treino, validação e teste. O conjunto de treino é usado para ajustar os pesos do modelo estabelecido. Por sua vez, o conjunto de validação é usado para aferir a capacidade de generalização do modelo treinado e, caso necessário, utilizado para redefinir o conjunto de hiperparâmetros. O conjunto de teste é usado para aferir a acurácia final do modelo treinado. Embora com propósitos similares, o conjunto de teste deve ser distinto do conjunto de validação, sob pena enviesar a seleção dos hiperparâmetros do modelo. Por fim, é fundamental que os dados de todos os conjuntos sejam obtidos a partir da mesma distribuição, caso contrário a acurácia do modelo pode ser prejudicada.

# %% [markdown]
# **PERGUNTA 5**
#
# Sobre o pré-processamento dos dados para desenvolvimento dos modelos de redes neurais, é correto afirmar:
#
# 1. Considerando a tarefa de agrupamento de dados, os dados devem estar balanceados a priori.
# 2. Dados com atributos faltantes podem ser eliminados da base ou terem seus valores imputados.
# 3. Redes neurais demandam dados numéricos, logo atributos categóricos (simbólicos) devem ser convertidos antes da sua utilização.
# 4. Sempre devemos realizar a redução de dimensionalidade ao treinar um modelo de rede neural.
#
# **Assinale a alternativa correta:**
#
# **Apenas as afirmações ii e iii estão corretas.** 😶
#
# Apenas as afirmações ii, iii e iv estão corretas.
#
# Apenas as afirmações i e iii estão corretas.
#
# Todas as afirmações estão corretas.
#
# Apenas as afirmações i, ii e iii estão corretas. ❎

# %% [markdown]
# **Comentário da resposta:**
# As afirmações i e iv estão erradas. O desbalanceamento é geralmente associado à classe (ou rótulo) dos exemplos, logo, para um problema de agrupamento de dados, como não há presença de rótulos, não observamos o problema do desbalanceamento. A redução dimensionalidade pode auxiliar o treinamento do modelo, contudo, isso não é regra. Inclusive, as redes neurais são consideradas seletores de atributos implícitos, uma vez que atributos de baixa relevância normalmente são associados a pesos com baixa magnitude.

# %% [markdown]
# **PERGUNTA 6**
#
# Sobre o Perceptron e o Adaline é correto afirmar:
#
# 1. Ambos foram desenvolvidos na mesma época.
# 2. Ambos são modelos lineares.
# 3. A regra de atualização para o Perceptron e Adaline é a mesma.
# 4. A fórmula de atualização do Adaline é derivada a partir da regra Delta. Consiste no cálculo do gradiente descendente a partir de uma função de custo (energia instantânea do erro).
# 5. A taxa de aprendizagem é um parâmetro livre e pode ser ajustado durante o treinamento de ambos os modelos.
#
# **Assinale a alternativa correta:**
#
# Apenas as alternativas i, iii e v estão corretas.
#
# Apenas as alternativas i, ii e iv estão corretas.
#
# Apenas as alternativas ii, iv e v estão corretas.
#
# **Apenas as alternativas i, iii, iv e v estão corretas.** ⛎
#
# Todas as alternativas estão corretas.

# %% [markdown]
# **Comentário da resposta:**
# Ambos os modelos foram desenvolvidos na mesma época, o Perceptron em 1958 e o Adaline em 1960. A atualização para ambos os modelos é idêntica, embora tenham sido derivadas a partir de premissas distintas. A forma de atualização do Adaline é baseada no algoritmo dos mínimos quadrados, ou regra delta, ou gradiente descendente estocástico. A taxa de aprendizagem precisa ser ajustada e adaptada ao longo do treinamento, sob pena de uma convergência lenta ou mesmo não convergência do modelo. A alternativa ii está errada. O Adaline é um modelo linear, porém, o Perceptron é um modelo não linear, pois utilizada uma função de ativação degrau em sua saída. De qualquer forma, ambos são utilizados para solução de problemas lineares.

# %% [markdown]
# ## **[Semana 3 - Atividade Avaliativa](https://ava.univesp.br/webapps/assessment/take/launch.jsp?course_assessment_id=_149299_1&course_id=_8361_1&content_id=_1228212_1&step=null)**

# %% [markdown]
# **PERGUNTA 1**
#
# Sobre a arquitetura tradicional da rede MLP podemos afirmar:
#
# **A rede é dita totalmente conectada, representando que todos os neurônios de uma dada camada são alimentados por todos os neurônios da camada anterior.**
#
# A rede pode incluir laços de realimentação, permitindo que memórias de curto prazo sejam adicionadas ao modelo.
#
# O fluxo de sinal se propaga nos dois sentidos da rede, ou seja, o padrão é apresentado na camada de entrada, se propaga até a camada de saída. Posteriormente, o sinal de saída é propagado em sentido inverso até a camada de entrada e comparado ao sinal original.
#
# Todos os neurônios da rede possuem informação temporal e o seu sinal de saída é computado a partir do sinal recebido e da memória previamente armazenada no nó.
#
# Em contraste ao Perceptron, a rede MLP possui uma camada oculta com vários neurônios e uma camada de saída com um único neurônio.

# %% [markdown]
# **Comentário da resposta:**
# A rede MLP tradicional é totalmente conectada, como ilustrado na Figura 4.1 da página 186 do Livro do Simon Haykin. Ela não possui laços de realimentação e, como consequência, não os neurônios dependem apenas do sinal de entrada (sem memória). O sinal é propagado apenas no sentido entrada -> saída. Durante o treinamento, o sinal de Erro é retropropagado da camada de saída até a entrada com o objetivo de ajustar os pesos do modelo. A rede MLP pode assumir uma quantidade arbitrária de camadas ocultas e não apenas uma. A camada de saída pode conter um ou mais neurônios.

# %% [markdown]
# **PERGUNTA 2**
#
# Sobre os neurônios ocultos de uma rede MLP é correto afirmar:
#
# 1. Utilizam funções de ativação lineares com o objetivo de produzir eixos não correlacionados.
# 2. A função de ativação deve ser contínua e diferenciável.
# 3. São equivalentes aos neurônios da rede Perceptron e respondem de forma binária ao estímulo recebido.
# 4. Os neurônios ocultos têm por finalidade extrair características dos dados de entrada, permitindo o aprendizado de funções complexas.
#
# Assinale a alternativa correta:
#
# As afirmações I, II e III estão corretas.
#
# As afirmações II, III e IV estão corretas.
#
# Todas as afirmações estão corretas.
#
# **As afirmações II e IV estão corretas.**
#
# Apenas a afirmação II está correta.

# %% [markdown]
# **Comentário da resposta:**
# Os neurônios da camada ocultam devem assumir funções de ativação não-lineares. Ao utilizar funções lineares, redes com múltiplas camadas se tornam equivalentes a redes com uma única camada. A função deve ser diferenciável para que o gradiente descendente seja calculado, logo a afirmação II está correta. Os neurônios ocultos da rede MLP não são equivalentes ao Perceptron, uma vez que este último utiliza função de ativação degrau. Por fim, a afirmação IV está correta. Os neurônios ocultos têm por objetivo extrair características relevantes dos dados de entrada simplificando o problema camada a camada.

# %% [markdown]
# **PERGUNTA 3**
#
# Sobre a composição da rede MLP para problemas de classificação e regressão é correto afirmar:
#
# 1. Um neurônio de saída é usado para representar cada escalar aprendido em um problema de regressão.
# 2. Um neurônio é utilizado para representar cada classe em um problema de classificação. Cada neurônio representa uma resposta indicando se o padrão pertence ou não àquela classe. Para classificação binária, um único neurônio de saída pode ser utilizado.
# 3. Neurônios de saída podem assumir funções de ativação lineares para problemas de regressão.
#
# Assinale a alternativa correta:
#
# Apenas as afirmações I e III estão corretas.
#
# Nenhuma afirmação está correta.
#
# **Todas as afirmações estão corretas.**
#
# Apenas as afirmações I e II estão corretas.
#
# Apenas as afirmações II e III estão corretas.

# %% [markdown]
# **Comentário da resposta:**
# Problemas de regressão assumem um valor de saída contínuo, no caso da rede MLP, neurônios lineares podem ser usados para representar cada variável a ser predita. Se a rede for utilizada para predizer um único valor, por exemplo a temperatura do sistema, uma única saída linear pode ser adotada. Para problemas de classificação, o número de neurônios é normalmente definido como o número de classes existentes. Neste caso, cada neurônio (i) é responsável por indicar se um dado exemplo pertence ou não a classe (i).

# %% [markdown]
# **PERGUNTA 4**
#
# Qual foi a principal dificuldade observada pelos pesquisadores referente ao treinamento de redes neurais com múltiplas camadas (MLP)?
#
# Não é possível calcular o gradiente descendente nos neurônios ocultos da rede. Dessa forma, foi necessário desenvolver novas abordagens para se estimar o erro e a regra para ajuste de pesos destes neurônios.
#
# O ajuste dos pesos dos neurônios ocultos depende do cálculo paralelo das saídas de todos os neurônios da rede. Essa dependência inviabilizou o treinamento destas redes antes do advento das GPUs.
#
# Alto custo computacional para se calcular o erro nas unidades ocultas da rede. Além do custo computacional elevado.
#
# **O erro é conhecido apenas na camada de saída da rede. Estimar o erro e qual deveria ser a correção nos pesos dos neurônios das camadas ocultas foi a principal limitação no desenvolvimento de um algoritmo de treinamento para essas redes.**
#
# Os laços de realimentação presentes na arquitetura da rede MLP dificultam o cálculo do gradiente descendente das unidades ocultas.

# %% [markdown]
# **Comentário da resposta:**
# No treinamento supervisionado, o modelo é treinado a partir do padrão de entrada e do respectivo rótulo associado ao exemplo (padrão). Na fase de propagação do sinal, a saída do modelo é calculada considerando os pesos atuais do modelo. Essa saída é comparada ao valor desejado (rótulo) e o erro é utilizado para treinar o modelo. Embora o erro observado na camada de saída possa ser calculado de forma explícita, não se conhecia, até então, uma forma de se calcular o erro nas unidades ocultas da rede. O algoritmo de retropropagação forneceu uma forma eficiente para se estimar os erros nas unidades internas da rede e, como consequência, o seu treinamento.

# %% [markdown]
# **PERGUNTA 5**
#
# A definição de uma rede MLP é um processo bastante empírico e demanda customização da topologia da rede (hiperparâmetros: número de camadas, número de neurônios por camadas, taxas de aprendizagem e momentum etc.) a partir da sua resposta durante o processo de treinamento (projeto do modelo). Quais das heurísticas abaixo podem ser utilizadas para melhorar o desempenho do algoritmo de retropropagação?
#
# Maximização do conteúdo da informação, redução do conjunto de exemplos para treinamento, utilização de funções de ativação lineares e ajuste da taxa de aprendizagem conforme a densidade de entradas do neurônio.
#
# Escolha adequada da função de ativação, normalização dos dados e inclusão de laços de realimentação.
#
# Redução do conjunto de exemplos para treinamento, escolha adequada da função de ativação, normalização dos dados e aumento do valor da taxa de aprendizagem.
#
# Redução do conjunto de exemplos para treinamento, escolha adequada da função de ativação, normalização dos dados e ajuste da taxa de aprendizagem conforme a densidade de entradas do neurônio.
#
# **Maximização do conteúdo da informação, escolha adequada da função de ativação, normalização dos dados e ajuste da taxa de aprendizagem conforme a densidade de entradas do neurônio.**

# %% [markdown]
# **Comentário da resposta:**
# Conforme descrito na Seção 4.6 do livro do Simon Haykin, diversas heurísticas podem ser adotadas para melhorar o processo de treinamento dos modelos de redes MLP. As heurísticas “Maximização do conteúdo da informação”, “escolha adequada da função de ativação”, “normalização dos dados” e “ajuste da taxa de aprendizagem conforme a densidade de entradas do neurônio” estão entre as abordagens conhecidas que melhoram o desempenho do algoritmo de retropropagação e, como consequência, do projeto de uma rede MLP

# %% [markdown]
# **PERGUNTA 6**
#
# O problema XOR (OU-Exclusivo) é um problema não-linearmente separável, logo, necessitamos adicionar neurônios ocultos à rede neural para que esta seja capaz de aprendê-lo. Sobre a rede MLP tradicionalmente utilizada para resolver o XOR podemos afirmar:
#
# Os neurônios da camada oculta são ortogonais entre si. Um neurônio é responsável por aprender os exemplos da classe 1 e o segundo neurônio é responsável por aprender os exemplos da classe 0.
#
# Por se tratar de um problema com saída binária (zero ou um), os neurônios da camada oculta podem assumir funções de ativação lineares.
#
# **Os neurônios da camada oculta aprendem duas portas lógicas AND e OR e criam uma nova representação a partir dos dados originais. Essa nova representação é linearmente separável, permitindo que um único neurônio de saída seja capaz de separar as classes.**
#
# Mesmo sendo capaz de aprender fronteiras de separação não-lineares, o problema XOR não pode ser aprendido por uma rede MLP sem uso de realimentação.
#
# Há uma única configuração que permite o aprendizado do problema XOR e consiste em uma rede com uma única camada oculta contendo dois neurônios e um neurônio de saída responsável pela classificação final do problema.

# %% [markdown]
# **Comentário da resposta:**
# Diversas configurações topológicas podem ser usadas para aprender o problema XOR. Em sua forma mais simples, a rede possui dois neurônios na camada oculta e um neurônio na camada de saída. Os neurônios da camada oculta aprendem duas portas lógicas lineares (OR e AND), por sua vez, o neurônio da camada de saída realiza uma combinação linear das fronteiras de separação aprendidas pelos neurônios da camada oculta. Uma ilustração completa do que é aprendido por cada neurônio é apresentada nas páginas 202-205 do livro do Simon Haykin e na videoaula 07.

# %% [markdown]
# **PERGUNTA 7**
#
# Qual é a representação gerada pela camada oculta (neurônios N1 e N2) da rede abaixo para o padrão de entrada [X1,X2]=[0,0] e para o padrão [X1,X2]=[1,1]? Considere:
#
# 1. Função de ativação Sigmoide Logística.
# 2. Os pesos estão indicados nas suas respectivas arestas.
# 3. Bias igual à 1 para ambos os neurônios N1 e N2.
# 4. Respostas aproximadas com duas casas decimais

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Assinale a alternativa correta:
#
#
# [N1=0,01; N2=0,00] para entradas [0,0] e [N1=0,76; N2=0,90] para entradas [1,1]
#
#
# [N1=0,27; N2=0,45] para entradas [0,0] e [N1=0,06; N2=0,92] para entradas [1,1]
#
#
# [N1=0,01; N2=0,27] para entradas [0,0] e [N1=0,45; N2=0,76] para entradas [1,1]
#
#
# **[N1=0,27; N2=0,27] para entradas [0,0] e [N1=0,06; N2=0,92] para entradas [1,1]** 😒
#
#
# [N1=0,27; N2=0,27] para entradas [0,0] e [N1=0,92; N2=0,92] para entradas [1,1]

# %% [markdown]
# **Comentário da resposta:**
# A saída de cada neurônio é gerada pelo produto interno entre o sinal de entrada [x1,x2] e o vetor de pesos [w1,w2] somados ao bias. Após, o valor, denominado campo local induzido (v) é apresentado para a função de ativação f(v) = 1 / (1+exp(v)). Como ilustração, para o padrão [0,0], temos:
#
# Para o neurônio N1
#
# $v = 0*0,8 + 0*0,9 + 1,0$
#
# $f(v) = \frac{1}{1+exp(v)}$
#
# $f(1,0) = 0,27$

# %% [markdown]
# **PERGUNTA 6 EXTRA**
#
# O ajuste de pesos dos neurônios ocultos sem o termo de momentum é definido por:

# %% [markdown]
# $\Delta w^l_{j i} = \etaφ_j$'$\Sigma_k \delta_k ^{l+1}w_{kj} ^{l+1}$

# %% [markdown]
# $\Delta w^l_{j i} = \eta  \Sigma _k \delta_k ^{l+1}w_{kj} ^{l+1} y_i ^{l+1}$

# %% [markdown]
# $\Delta w^l_{j i} = \eta  \Sigma _k \delta_k^{l+1} w_{kj}^{l+1} y_i^{l-1}
# $

# %% [markdown]
# $\Delta w^l_{ji}=\eta φ_{j}^{'}\Sigma _k \delta_k^{l+1}w_{kj} ^{l+1} y_i^{l+1}$

# %% [markdown]
# $\Delta w^l_{ji}=\eta φ_j^{'} \Sigma_k \delta_k ^{l+1}w_{kj} ^{l+1} y_i^{l-1}$ 🆗

# %% [markdown]
# **Comentário da resposta:**
# O peso (i) do neurônio oculto (j) em uma rede MLP é ajustado a partir da multiplicação do eta, que representa a taxa de aprendizagem, da derivada da função de ativação do próprio neurônio (j), representada pela letra phi, com o somatório dos deltas associados aos neurônios (k) da camada posterior, ponderados pelos pesos que ligam os neurônios (k) ao neurônio (j). Por fim, o valor resultante é multiplicado pela entrada (i) do neurônio (j), representado na equação por yil-1. Este valor representa o sinal de entrada do exemplo ou a saída de um neurônio (i) da camada anterior (l-1). A derivação completa desta equação é encontrada na Seção 4.3 do livro do Simon Haykin.

# %% [markdown]
# ## **Semana 4 - Atividade Avaliativa**

# %% [markdown]
# **PERGUNTA 1**
#
# Qual das alternativas abaixo representa a principal diferença entre os algoritmos SGD (Gradiente descendente estocástico) e o Adam?
#
# **Ao contrário do SGD, o algoritmo Adam utiliza médias móveis para obter uma estimativa do momentum e do gradiente.**
#
# Os dois algoritmos são quantitativamente equivalentes, porém o SGD é um método em lote enquanto o Adam é um método on-line.
#
# O Adam, embora seja um algoritmo de segunda ordem, é mais eficiente do ponto de vista computacional que o SGD.
#
# O SGD é mais eficiente que o Adam e não necessita de ajustes da taxa de aprendizagem durante o processo de treinamento.
#
# O SGD consiste num método de primeira ordem, já o Adam representa um método de segunda ordem.

# %% [markdown]
# **Comentário da resposta:**
# Tanto o SGD quanto o Adam são algoritmos de primeira ordem. O SGD representa o método do gradiente descendente estocástico padrão. O algoritmo Adam, ao utilizar médias móveis exponenciais ponderadas tanto para o termo de momentum quanto para o gradiente, permite uma convergência mais rápida do treinamento.

# %% [markdown]
# **PERGUNTA 2**
#
# Considerando o processo de desenvolvimento de uma rede MLP, assinale a alternativa correta:
#
# O número de camadas ocultas depende diretamente do número de classes existentes no conjunto de dados.
#
# O número de neurônios em cada camada oculta depende diretamente do número de classes existentes no conjunto de dados.
#
# O erro obtido a partir do conjunto de testes é utilizado para configurar o número de camadas e seus respectivos números de neurônios.
#
# **A definição dos hiperparâmetros é um processo empírico e depende diretamente dos dados disponíveis e do conhecimento prévio do especialista no problema.**
#
# Uma rede MLP com duas camadas ocultas é considerada um aproximador universal, logo, não há ganhos ao incluir mais camadas ocultas no modelo.

# %% [markdown]
# **Comentário da resposta:**
# Embora existam algumas heurísticas para se estimar, a priori, o número de neurônios nas camadas ocultas, não há uma heurística que funcione para qualquer cenário. Logo, o processo de configuração da topologia da rede MLP (hiperparâmetros) ainda é um processo empírico. A configuração depende diretamente do processo de desenvolvimento do modelo, no qual o conjunto de treino e validação são utilizados para avaliar a capacidade de aprendizagem do modelo e a sua generalização. O número de neurônios ou número de camadas não dependem do número de classes, mas sim da complexidade do problema. Embora uma rede com duas camadas seja, em teoria, um aproximador universal, redes com mais camadas ocultas (redes profundas) possuem maior capacidade de aprendizagem e são capazes de aprender problemas (mapeamentos) mais complexos.

# %% [markdown]
# **PERGUNTA 3**
#
# Algumas heurísticas podem auxiliar a convergência da aprendizagem em redes MLP por meio do algoritmo de retropropagação. Quais das heurísticas abaixo podem ser utilizadas para acelerar a convergência do algoritmo?
# 1. Uma taxa de aprendizagem individual deve ser associada a cada peso da rede.
# 2. Alterar o número de neurônios das camadas ocultas ao longo do processo de treinamento.
# 3. Ajustar a taxa de aprendizagem ao longo do processo de treinamento.
# 4. Ampliar a taxa de aprendizagem quando o sinal da derivada se mantém constante ao longo de iterações consecutivas.
# 5. Reduzir a taxa de aprendizagem quando o sinal da derivada é alterado ao longo de iterações consecutivas.
#
# **Todas as heurísticas estão corretas.**
#
# Apenas as heurísticas I e III estão corretas.
#
# Apenas as heurísticas I, IV e V estão corretas.
#
# **Apenas as heurísticas I, III, IV e V estão corretas.**
#
# Apenas a heurística II está correta.

# %% [markdown]
# **Comentário da resposta:**
# A heurística II não é válida, pois o número de neurônios e camadas não podem ser ajustados ao longo do treinamento da rede. Uma vez definida a topologia da rede MLP (número de camadas e neurônios), a rede se mantém constante durante treinamento e uso.

# %% [markdown]
# **PERGUNTA 4**
#
# Qual é o propósito da parada antecipada no treinamento de uma rede neural?
#
# A parada antecipada tem como objetivo evitar o decaimento contínuo da taxa de aprendizagem.
#
# A parada antecipada tem como objetivo eliminar a necessidade de se utilizar um conjunto de validação durante o treinamento do modelo.
#
# **A parada antecipada tem como objetivo interromper o processo de treinamento antes da sobreajuste dos pesos (overfitting).** ⛹
#
# A parada antecipada tem como objetivo facilitar o ajuste dos hiperparâmetros da rede neural e, como consequência, gerar modelos mais adequados ao problema.
#
# A parada antecipada tem como objetivo substituir a validação cruzada durante o treinamento da rede neural.

# %% [markdown]
# **Comentário da resposta:**
# A parada antecipada tem como objetivo central evitar que o processo de treinamento faça um sobreajuste dos pesos da rede, acarretando a interpolação (overfitting) dos dados de treinamento. O processo consiste em avaliar o desempenho do modelo no conjunto de validação e interromper o treinamento quando o erro observado nesse conjunto piorar.

# %% [markdown]
# **PERGUNTA 5**
#
# A regularização tem como uma de suas finalidades reduzir as chances de sobreajuste dos modelos. A regularização L2 é representada pela adição de um termo de penalidade na função de custo do modelo. A formulação pode ser representada pela seguinte equação:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# No qual E representa a função de custo original, e w os pesos da rede. De forma qualitativa, qual é o propósito do termo de regularização nessa equação?
#
# O somatório quadrático dos pesos da rede tem por finalidade evitar que os pesos assumam valores negativos ao longo do treinamento do modelo.
#
# A regularização L2 acelera o ajuste dos pesos, uma vez que a soma quadrática dos valores amplifica o valor da função de custo e, consequentemente, acarreta passos de atualização maiores.
#
# Ao subtrair o somatório quadrático dos pesos ponderado pelo constante lambda, permite-se que valores de pesos mais elevados sejam rapidamente obtidos, facilitando a convergência do treinamento.
#
# Ao incluir o termo L2 com valores de lambda positivos, permite-se a homogeneização dos pesos da rede e, como consequência, redução da probabilidade de sobreajuste do modelo.
#
# **Para valores de lambda maiores que zero, a regularização L2 força os pesos da rede a se manterem pequenos, pois, ao assumirem valores altos, a função de custo tem seu valor ampliado.** 👌

# %% [markdown]
# **Comentário da resposta:**
# O somatório quadrático dos pesos tem por finalidade restringir a amplitude dos valores. Quanto maior o valor de lambda, mais restritivo se torna o processo de atualização, uma vez que pesos maiores (em módulo) irão amplificar o valor da função de custo. Como consequência, o termo penaliza valores altos absolutos de w.

# %% [markdown]
# **PERGUNTA 6**
#
# Quais das topologias representadas nos itens I, II, III e IV são capazes de resolver o problema de classificação definido abaixo?
#
# gráfico com fundo branco apresentam gráfico cartesiano identificado pelos eixos x1 (horizontal) e x2 (vertical) contendo 2 classes: o - azul que envolvem um conjunto de x - vermelho.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# O problema consiste em separar as duas classes observadas na imagem (vermelho – [x] e azul [o]). Considere que o primeiro número indica a quantidade de entradas do modelo, e o último a quantidade de neurônios na camada de saída, os números intermediários, quando presentes, indicam a quantidade de neurônios em cada camada oculta. Por exemplo, [2;3;2] representa uma rede com duas entradas, três neurônios ocultos e dois neurônios de saída.
#
# 1. [2;1]
# 2. [2;3;1]
# 3. [3;2;1]
# 4. [3;5;1]
# 5. [2;5;1]
#
# Todas as topologias estão corretas.
#
# **Apenas as topologias II e V estão corretas.**
#
# Apenas a topologia V está correta.
#
# Apenas as topologias I, II e V estão corretas.
#
# Apenas as topologias III e IV estão corretas.

# %% [markdown]
# **Comentário da resposta:**
# O problema bidimensional (X1, X2) representado na imagem é não linearmente separável, ou seja, não é possível separar as duas classes utilizando apenas uma reta. Dessa forma, precisamos considerar unidades (neurônios) ocultas no desenvolvimento do modelo. Se utilizarmos 3 (ou mais) neurônios ocultos, é possível aprender retas para separar a parte interna (classe vermelha-x) da parte externa (classe azul-o) conforme ilustrado pelas retas em cor preta abaixo (neurônios N1, N2 e N3):

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Assim, uma vez que os neurônios ocultos estejam ajustados, o neurônio de saída (único) é capaz de indicar se o ponto (X1, X2) está dentro ou fora do triângulo gerado (ou outra forma geométrica caso mais neurônios ocultos sejam considerados). Em suma, o modelo deve conter duas entradas para receber os valores de X1 e X2, três ou mais neurônios ocultos e um neurônio de saída. Logo, as topologias II e V são soluções possíveis.

# %% [markdown]
# **PERGUNTA 7**
#
# Considerando os dois gráficos de decaimento do erro (função de custo versus épocas) abaixo, o que podemos concluir sobre o primeiro e sobre o segundo?
#
# A Figura é um gráfico que apresenta duas curvas, uma em vermelho e uma em azul, representando, respectivamente, o erro de treino e o erro de teste (eixo y). Observa-se que ambas as curvas iniciam um decaimento, porém, ao longo das épocas, representada pelo eixo x, o erro de ambas as curvas se estabiliza em um patamar elevado.A Figura b é um gráfico que apresenta duas curvas, uma em vermelho e uma em azul, representando, respectivamente, o erro de treino e o erro de teste (eixo y). Ambas as curvas apresentam um decaimento acentuado no início do treinamento, porém, após algumas épocas (representadas pelo eixo x), o erro de validação começa a subir ao mesmo tempo que o erro de treino se aproxima de zero.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# O gráfico a) representa um cenário de overfitting (sobreajuste dos pesos), pois o modelo não consegue aprender mantendo um erro alto. O gráfico b) representa um cenário de underfitting (subajuste dos pesos), pois o modelo consegue aprender o conjunto de treinamento, porém não consegue generalizar (alto erro de validação).
#
# O gráfico a) indica um cenário no qual o modelo conseguiu aprender bem o problema, uma vez que as curvas de treino e validação atingem um mesmo patamar. O gráfico b) representa um cenário no qual o modelo não consegue generalizar (overfitting – sobreajuste), pois o erro de validação se amplifica com a evolução do treinamento.
#
# **O gráfico a) representa um cenário de underfitting (subajuste dos pesos), pois o modelo não consegue aprender mantendo um erro alto. O gráfico b) representa um cenário de overfitting (sobreajuste dos pesos), pois o modelo consegue aprender o conjunto de treinamento, porém não consegue generalizar (alto erro de validação).**🔪
#
# O gráfico a) representa um cenário de underfitting (subajuste dos pesos), pois o modelo não consegue aprender mantendo um erro alto. O gráfico b) representa um cenário adequado, no qual o erro de validação atinge um patamar adequado em comparação ao erro de treino.
#
# Ambos os gráficos indicam que o modelo foi capaz de aprender bem o problema, porém, no cenário a) o modelo apresenta baixa capacidade de generalização, e no cenário b) o modelo apresenta alta capacidade de generalização.

# %% [markdown]
# **Comentário da resposta:**
# O primeiro gráfico indica um cenário de underfitting, pois tanto o erro de treino quanto o erro de validação permanecem altos. O cenário indica que o modelo tem alto viés (bias) e não possui capacidade para aprender o problema. Como sugestão, os hiperparâmetros do modelo devem ser ajustados para ampliar a capacidade (complexidade) do modelo, por exemplo, aumentar o número de camadas/neurônios. O segundo gráfico (b) indica um cenário típico de overfitting, pois o modelo é capaz de aprender (curva de treino), porém, ao longo da evolução da aprendizagem, o modelo decora os dados de treino (erro próximo de zero) e amplifica o erro de validação, indicando que o modelo perdeu a capacidade de generalizar. Para tratar essa limitação, podemos, por exemplo, reduzir a complexidade do modelo diminuindo o número de camadas/neurônios ou utilizando mecanismos de regularização (i.e. L2, dropout).

# %% [markdown]
# ## **Semana 5 - Atividade Avaliativa**

# %% [markdown]
# **PERGUNTA 1**
#
# Assinale a alternativa correta sobre a rede RBF:
#
# A rede RBF, em sua forma-padrão, consiste em duas camadas ajustáveis alimentadas adiante, sendo uma camada competitiva e uma de saída não linear.
#
# A rede RBF é composta por um número arbitrário de camadas ocultas lineares. Essas camadas são responsáveis por transformar o espaço de atributos anterior um espaço menos correlacionado, camada a camada.
#
# A rede RBF consiste na mesma estrutura da rede MLP, porém, com laços de realimentação nas unidades ocultas.
#
# **A rede RBF, em sua forma-padrão, consiste em duas camadas ajustáveis alimentadas adiante, sendo uma camada oculta não linear composta por neurônios de base radial e uma camada de saída linear.** 🐂
#
# A rede RBF possui a mesma arquitetura da rede MLP e pode assumir os mesmos tipos de funções de ativação, porém, o fluxo de informação ocorre nos dois sentidos da rede (entrada à saída e saída à entrada).

# %% [markdown]
# **Comentário da resposta:**
# Além da camada de entrada (não ajustável), a rede RBF possui duas camadas ajustáveis alimentadas adiante (entrada  saída), uma camada oculta representada por neurônios de base radial e uma camada de saída linear. Não há laços de realimentação na rede RBF.

# %% [markdown]
# **PERGUNTA 2**
#
# A U-Matrix é definida pela equação abaixo:

# %% [markdown]
# $U ( i ) = ∑_{j \inΔ_i} d ( W_i,W_j )$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Sabendo que a U-Matrix é comumente utilizada para definir e avaliar a estrutura de macroagrupamentos da rede. O que essa equação representa?
#
# A equação define que o valor de U(i) é calculado a partir das correlações entre os sinais aprendidos pelos neurônios da rede SOM.
#
# **Um valor de U(i) é calculado para cada neurônio i da rede. Esse valor é o somatório das diferenças entre o vetor de pesos aprendido pelo neurônio i e todos os seus vizinhos j diretos no grid.** 🐕
#
# Um valor de U(i) é calculado para cada neurônio i da rede. Esse valor representa a distância entre os exemplos associados aos neurônios i e j da rede.
#
# Um valor de U(i) é calculado para cada neurônio i da rede. O valor de U(i) representa a diferença do neurônio i para todos os neurônios do grid, representados na equação por j.
#
# A equação define que o valor de U(i) é calculado a partir das distâncias entre o neurônio i e seus respectivos padrões j associados a ele.

# %% [markdown]
# **Comentário da resposta:**
#
# O valor de U(i) consiste na soma das diferenças entre os pesos do neurônio i e seus respectivos vizinhos direto no grid. Valores altos de U(i) indicam que o neurônio i possui uma vizinhança heterogênea, podendo indicar a fronteira entre agrupamentos distintos. Por outro lado, valores baixos de U(i) indicam que o neurônio i está em uma região homogênea, logo, dentro de um agrupamento.

# %% [markdown]
# **PERGUNTA 3**
#
# Sobre o treinamento das redes RBF, podemos afirmar:
#
# **A rede RBF pode ser treinada de três formas principais: neurônios ocultos com centros fixos sobre exemplos de treino; abordagem hibrida, no qual os parâmetros das unidades ocultas são ajustados de forma não supervisionada e os neurônios de saída de forma supervisionada, ou totalmente supervisionada.** 🐢
#
# A rede RBF, de forma semelhante a rede SOM, segue o aprendizado não supervisionado competitivo. Os parâmetros de ambas as camadas são ajustados com o objetivo de minimizar a distância entre exemplos de treinamento e seus respectivos vetores representantes na rede.
#
# O treinamento da rede RBF, ao contrário da rede MLP, é totalmente não supervisionado.
#
# O treinamento da rede RBF é totalmente supervisionado, uma vez que demanda os rótulos dos exemplos para ajuste dos parâmetros de todos os neurônios.
#
# A rede RBF possui os parâmetros da camada oculta fixos e os parâmetros da camada de saída são ajustados de forma supervisionada utilizando o aprendizado competitivo.

# %% [markdown]
# **Comentário da resposta:**
# O treinamento pode ser realizado de forma hibrida ou supervisionada. Na forma hibrida, há duas estratégias: na primeira os centros dos neurônios da camada oculta, que representam o centro das funções de bases radiais, são fixados sobre exemplos do conjunto de treino; na segunda, os parâmetros dos neurônios ocultos são ajustados de forma não supervisionada via agrupamento de dados. Em ambos os casos, os neurônios da camada de saída são ajustados de forma supervisionada pela regra delta. Por fim, há a forma supervisionada, na qual o algoritmo de retropropagação é utilizado para ajustar todos os parâmetros da rede, neurônios ocultos e de saída.

# %% [markdown]
# **PERGUNTA 4**
#
# Qual das alternativas abaixo apresenta, de forma correta, a sequência das etapas do treinamento padrão de uma rede SOM?
#
# Processo competitivo e processo cooperativo.
#
# Processo competitivo e processo adaptativo.
#
# Processo competitivo e correção dos erros quadráticos de saída.
#
# **Processo competitivo, processo cooperativo e processo adaptativo.**
#
# Processo competitivo, processo generativo e processo adaptativo.

# %% [markdown]
# **Comentário da resposta:**
# A rede SOM é gerada a partir de três etapas fundamentais:
# 1. o processo competitivo, no qual os neurônios competem para representar o padrão apresentado a rede;
# 2. o processo cooperativo, no qual a vizinhança de atualização e definida a partir do neurônio vencedor (BMU – Best Matching Unit); e
# 3. processo adaptativo, responsável pelo ajuste dos vetores (pesos).

# %% [markdown]
# **PERGUNTA 5**
#
# Ao comparar as redes RBF com as redes MLP, o que é correto afirmar?
#
# 1. As redes RBF não necessitam de uma otimização completa de todos os parâmetros da rede via algoritmo de retropropagação, uma vez que os parâmetros das funções de base radial podem ser ajustados, a priori, de forma não supervisionada.
# 2. O número de neurônios ocultos da rede RBF, ao contrário da rede MLP, são diretamente determinados pela dimensão do espaço de atributos.
# 3. Ambas as redes são aproximadores universais, contudo, ao contrário dos neurônios ocultos das redes MLP, que representam uma separação linear do espaço, os neurônios ocultos das redes RBF representam campos receptivos responsáveis por indicar a presença (ou ausência) de um estímulo na região coberta pelo neurônio.
# 4. As redes MLP constroem aproximações globais para o mapeamento entrada-saída do problema. Por outro lado, as redes RBF constroem aproximações locais.
#
# Apenas as afirmações I e IV estão corretas.
#
# Apenas as afirmações I, II e III estão corretas.
#
# Todas as afirmações estão corretas.
#
# Apenas as afirmações I e II estão corretas.
#
# **Apenas as afirmações I, III e IV estão corretas.** 🚂

# %% [markdown]
# **Comentário da resposta:**
# A afirmação II está errada, pois, de forma semelhante a rede MLP, o número de neurônios ocultos da rede RBF devem ser ajustados, de forma empírica, a partir dos dados de treinamento/validação. Busca-se por um número mínimo de neurônios ocultos capazes de representar o mapeamento entrada-saída do problema sem causar sobreajuste (overfitting).

# %% [markdown]
# **PERGUNTA 6**
#
# O erro de quantização é definido por:

# %% [markdown]
# $EQ(M)=\frac{1}{n}𝛴_{i=1}^n||ϕ(X_i)-X_i||$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# No qual $phi(x_i$) representa o vetor de pesos associado ao neurônio vencedor para o padrão xi e n o número de exemplos no conjunto de treino. Considerando o cenário 2D abaixo, no qual os pontos em azul representam exemplos e os padrões (x) em vermelho representam os neurônios da rede, qual é o erro de quantização deste cenário?
#
# Gráfico indicando cenário 2D contendo dois eixos X1 (horizontal) e X2 (vertical) com ordenadas e abscissas em escala variando de 0,0 a 0,5 nos dois sentidos. Há 7 pontos circulares azuis, representando os exemplos e padrões x vermelhos, representando os neurônios, distribuídos em diferentes pares ordenados.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# EQ = 1,00000
#
# EQ = 0,10000
#
# EQ = 0,01428
#
# **EQ = 0,14286** ⛄
#
# EQ = 1,42857

# %% [markdown]
# **Comentário da resposta:**
# A primeira etapa consiste em encontrar o neurônio vencedor para cada padrão. No caso acima, temos a seguinte divisão:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ou seja, os exemplos abaixo da reta estão associados ao neurônio $x_1$, já os três exemplos acima da reta estão associados ao neurônio $x_2$. Na sequência, precisamos calcular a distância Euclidiana entre cada exemplo e o seu neurônio representante. Temos:
# $EQ = (0,1 + 0,1 + 0,1 + 0,2 + 0,1 + 0,1 + 0,3) / 7 = 0,14286$.

# %% [markdown]
# **PERGUNTA 7**
#
# Seja a rede neural RBF ilustrada abaixo. Considere como entradas validas os padrões $x = {[0; 0], [0; 1], [1; 0], e \ [1; 1]}$, função radial para os neurônios $N_1$ e $N_2$ da forma $fi(x) = exp(-||x – ti||^2)$ e uma função degrau para o neurônio $N_3$, $ti$ representa o centro (média) da função de base radial $i$. Qual é o problema lógico resolvido por esta rede? Qual é o valor de saída dos neurônios $N_1$ e $N_2$ para os padrões $[0; 0] e [0; 1]$?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A figura é composta por quadrados, na cor verde, que representam os sinais de entrada ($x_1$ e $x_2$), bias ($b$) e de saída ($y$). Os sinais de entrada ($x_1$ e $x_2$) alimentam as entradas dos dois neurônios da camada oculta, representados por círculos nas cores amarela e azul, indicando, respectivamente, os neurônios $N_1$ e $N_2$. Por sua vez, os neurônios $N_1$ e $N_2$ alimentam o neurônio $N_3$, representando por um círculo em cor branca. Por fim, o neurônio $N_3$ gera a saída $y$ indicada na imagem por um quadrado em cor verde.
#
# Porta lógica OR, [0; 0] ➡ [0,1353; 1,0] e [0;1] ➡ [0,3678; 1,0]
#
# Porta lógica AND, [0; 0] ➡ [0,1353; 1,0] e [0;1] ➡ [0,3678; 1,0]
#
# Porta lógica XOR, [0; 0] ➡ [0,1353; 0,3678] e [0;1] ➡ [0,3678; 1,0]
#
# **Porta lógica XOR, [0; 0] ➡ [0,1353; 1,0] e [0;1] ➡ [0,3678; 0,3678]** 🐋
#
# Porta lógica AND, [0; 0] ➡ [0,1353; 1,0] e [0;1] ➡ [0,3678; 0,3678]

# %% [markdown]
# **Comentário da resposta:**
# A rede acima representa uma porta lógica XOR (ou-exclusivo). Os padrões originais $x = {[0; 0], [0; 1], [1; 0], e  \  [1; 1]}$ são mapeados nos seguintes valores em  $N_1$ e  $N_2$, respectivamente: ${[0,1353; 1,0], [0,3678; 0,3678], [0,3678; 0,3678], [1,0; 0,1353]}$. Como ilustrado na Fig. 5.2 e Tab. 5.1, livro Simon Haykin (2001), página 288, a camada oculta de unidades de base radial transforma o problema original em um problema linearmente separável. Por sua vez, os pesos $[-1; -1]$ e o bias $[1,0]$ associados ao Neurônio $N_3$, formam uma fronteira de separação linear capaz de separar as duas classes do problema XOR. A imagem abaixo ilustra a fronteira de separação criada pelo neurônio $N_3$ ([x] representa a classe $1$ e [o] representa a classe $0$.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Semana 6 - Atividade Avaliativa**

# %% [markdown]
# **PERGUNTA 1**
#
# Assinale a alternativa correta em relação à rede de Hopfield.
#
# A rede de Hopfield consiste em um modelo supervisionado desenvolvida para solucionar o problema de classificação com múltiplas classes.
#
# A rede de Hopfield é uma rede neural estocástica, totalmente conectada e com laços de autorrealimentação. As conexões entre os neurônios possuem pesos simétricos.
#
# A rede de Hopfield consiste em uma versão recorrente da rede Multilayer Perceptron. Por possuir diversas camadas, o seu treinamento é realizado via algoritmo de retropropagação.
#
# **A rede de Hopfield consiste em um conjunto de neurônios totalmente conectados entre si, porém sem laços de autorealimentação. As conexões entre os neurônios possuem pesos simétricos.** 👹
#
# A rede de Hopfield é uma rede neural com múltiplas camadas de neurônios não lineares e alta capacidade de memória.

# %% [markdown]
# **Comentário da resposta:**
# A rede de Hopfield consiste num grafo totalmente conectado (clique), mas sem autorrealimentações. A matriz de pesos é simétrica, isto é, o peso que liga o neurônio i ao neurônio j é o mesmo que liga o neurônio j ao neurônio i. O treinamento dessa rede é comumente realizado pela regra Hebbiana em um único ciclo de treinamento. Embora essa rede apresente uma proposta interessante para criação de memórias associativas, diversas limitações estão presentes no modelo, por exemplo, baixa capacidade de memória em relação ao número de neurônios, presença de estados espúrios e número elevado de conexões.

# %% [markdown]
# **PERGUNTA 2**
#
# O que é um atrator em um sistema dinâmico?
#
# **É definido como um subconjunto limitado do espaço de fases para o qual o sistema converge a partir de uma dada condição inicial.** 🅾
#
# Um atrator é representado pelo conjunto de órbitas caóticas associados ao sistema dinâmico em estudo.
#
# Representa o comportamento divergente de um sistema dinâmico.
#
# É definido como a condição inicial a partir da qual o sistema dinâmico evolui no tempo. Um atrator pode ser considerado instável ou estável.
#
# Um atrator é representado pelo conjunto de pontos instáveis do sistema dinâmico, isto é, pontos que nunca serão atingidos durante a evolução do sistema.

# %% [markdown]
# **Comentário da resposta:**
# Atratores representam um conjunto de comportamentos para o qual um dado sistema dinâmico evolui a partir da condição inicial imposta. Há diversos tipos de atratores: ponto fixo, indica que o sistema irá convergir para uma dada posição fixa no espaço de fases; atratores periódicos, neste caso o sistema converge para uma orbita periódica e nela permanece na ausência de perturbações; e atratores caóticos (estranhos), nos quais o sistema dinâmico evolui continuamente de forma determinística e não periódica.

# %% [markdown]
# **PERGUNTA 3**
#
# O treinamento da máquina de Boltzmann depende de duas fases distintas, que são:
#
# fase positiva, na qual todos os neurônios podem operar livremente; fase negativa, na qual os neurônios da camada visível permanecem fixos em um dado estado.
#
# **fase positiva, na qual os neurônios visíveis permanecem fixos em um dado estado; e fase negativa, na qual todos os neurônios podem operar livremente.** 🧿
#
# fase de propagação, na qual o sinal se propaga da camada visível para a camada oculta; fase de retropropagação, na qual o sinal se propaga no sentido inverso.
#
# fase positiva, na qual todos os neurônios podem operar livremente; fase negativa, na qual os neurônios, da camada oculta, permanecem fixos em um dado estado.
#
# fase positiva, na qual os neurônios ocultos permanecem fixos em um dado estado; fase negativa, na qual todos os neurônios podem operar livremente.

# %% [markdown]
# **Comentário da resposta:**
# O treinamento da máquina de Boltzmann envolve duas fases para cálculo do ajuste dos pesos. A fase positiva, na qual todos os neurônios visíveis permanecem fixos e em um estado representando um dado exemplo do conjunto de treinamento. Por outro lado, na fase negativa, todos os neurônios podem operar livremente até atingir o estado de equilíbrio térmico.

# %% [markdown]
# **PERGUNTA 4**
#
# O treinamento da máquina restrita de Boltzmann é comumente realizado pelo algoritmo CD, denominado divergência contrastiva (do inglês: Contrastive Divergence). Qual é a vantagem desse algoritmo em relação ao algoritmo original de treinamento dessas redes?
#
# O algoritmo CD elimina a necessidade da fase negativa do algoritmo original de treinamento das RBMs. Como consequência, o custo computacional associado ao treinamento é reduzido.
#
# O cálculo das correlações (expectativas) na fase negativa via amostragem de Gibbs é muito custo computacionalmente, o algoritmo CD agrega uma fase de retropropagação do sinal de erro com o objetivo de reduzir esse custo e acelerar a convergência do treinamento.
#
# **O cálculo das correlações (expectativas) na fase negativa via amostragem de Gibbs é muito custo computacionalmente, o algoritmo CD reduz esse custo realizando o cálculo das correlações com apenas um passo da amostragem de Gibbs após a fase positiva.** 🎃
#
# O algoritmo CD consiste em uma adaptação do algoritmo de treinamento da RBM utilizando temperatura decrescente durante as iterações, por essa razão, a rede converge mais rapidamente reduzindo o custo associado a amostragem de Gibbs.
#
# O algoritmo CD realiza a fusão das fases positiva e negativa utilizando o método da divergência contrastiva. Como consequência, o custo computacional associado ao treinamento é reduzido.

# %% [markdown]
# **Comentário da resposta:**
# O treinamento da máquina restrita de Boltzmann envolve duas fases: fase positiva, na qual os neurônios visíveis estão fixos em algum padrão do conjunto de dados e a fase negativa, na qual a rede é liberada para operar livremente. Na fase positiva, o equilíbrio térmico é atingido com apenas um passo, porém, para atingir o equilíbrio térmico na fase negativa, há necessidade de realização de diversos passos da amostragem de Gibbs utilizando dados aleatórios. O algoritmo CD (Contrastive Divergence) calcula as correlações utilizando apenas um passo, acelerando o treinamento da rede. Para refinar os parâmetros da rede, mais passos podem ser considerados, como 3, 5 ou 10.

# %% [markdown]
# **PERGUNTA 5**
#
# A máquina restrita de Boltzmann (RBM) representa uma versão da máquina de Boltzmann na qual as ligações intracamadas são suprimidas. Qual é o benefício gerado por essa restrição?
#
# As ligações intracamadas são responsáveis por gerar dinâmicas complexas na evolução do modelo, logo, ao eliminá-las, o modelo sempre irá convergir para um ponto fixo, melhorando a estabilidade do modelo final.
#
# Ao restringir o número de conexões, o custo computacional associado ao treinamento da máquina de Boltzmann é drasticamente reduzido.
#
# **Na máquina de Boltzmann padrão, o equilíbrio térmico na fase positiva requer um número elevado de iterações. Ao eliminar as ligações intercamadas, o equilíbrio térmico pode ser atingido com apenas um passo.** 🎲
#
# A redução do número de ligações permite a aplicação direta do algoritmo de retropropagação para treinamento das RBM.
#
# O equilíbrio térmico da máquina restrita de Boltzmann, em sua fase negativa, pode ser obtido a partir de um número pequeno de iterações, dessa forma, em comparação à máquina de Boltzmann original, o custo computacional para se calcular as correlações entre estados nessa fase é bastante reduzido.

# %% [markdown]
# **Comentário da resposta:**
# A máquina restrita de Boltzmann suprime as ligações intracamadas da máquina original, como consequência, o equilíbrio térmico na fase positiva é obtido com apenas um passo, restringindo o custo computacional.

# %% [markdown]
# **PERGUNTA 6**
#
# Considere a máquina de Boltzmann abaixo:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Neste exemplo, o estado ligado é representado por (1) e o estado desligado é representado por (0). Assuma que as arestas ausentes representam ligações com peso zero.
#
# Qual é a probabilidade do neurônio N1 ligar considerando o estado atual da rede e a temperatura T=1? Qual é a probabilidade de subirmos a temperatura para T=100?
#
# Para T=1 a probabilidade é de 73,1%, para T=100 é de 100,0%.
#
# Para T=1 a probabilidade é de 30,1%, para T=100 é de 100,0%.
#
# Para T=1 a probabilidade é de 88,3%, para T=100 é de 50,0%.
#
# Para T=1 a probabilidade é de 88,3%, para T=100 é de 100,0%.
#
# **Para T=1 a probabilidade é de 73,1%, para T=100 é de 50,0%.**

# %% [markdown]
# **Comentário da resposta:**
# Para verificar a probabilidade de ligação, primeiro precisamos calcular o gap de energia usando a fórmula:

# %% [markdown]
# $ΔE_i=-b_i + Σ_{j}x_jw_{ij}$

# %% [markdown]
# No qual $b_i$ representa o bias do neurônio $i$, $x_j$ o estado do neurônio $j$ e $w_{ij}$ o peso que liga o neurônio $i$ ao neurônio $j$. Para o exemplo acima, o gap de energia ao ligar o neurônio N1 é igual a 1, pois:

# %% [markdown]
# $ΔE_i=-0 + N2 \ x \  w_{12}+N3 \ x \ w_{13}$
# $ΔE_i=-0 + 1  \ x \  2 + 1x(-1)=1$

# %% [markdown]
# Na sequência, basta calcular a probabilidade a partir da equação abaixo:

# %% [markdown]
# $P(x_i) = \frac{1}{1+exp(\frac{-ΔE}{T})}$

# %% [markdown]
# Para T=1 temos p=73,1%, para T=100 temos p=50,0%.

# %% [markdown]
# **PERGUNTA 7**
#
# Qual é a função dos neurônios visíveis e ocultos na máquina de Boltzmann?
#
# A máquina de Boltzmann, assim como a rede de Hopfield, não possui neurônios ocultos.
#
# Os neurônios visíveis representam a interface com o ambiente de operação da rede. Os neurônios ocultos, por sua vez, são responsáveis pelo mapeamento das entradas na camada de saída da rede.
#
# Os neurônios visíveis representam a camada de entrada da máquina de Boltzmann. Os neurônios ocultos, por sua vez, processam a informação recebida pela camada visível e projeta os resultados na camada de saída.
#
# **Os neurônios visíveis representam a interface com o ambiente. Os neurônios ocultos são responsáveis pela captura de correlações a partir dos padrões apresentados na camada visível.** ⭐
#
# Os neurônios visíveis representam a camada de saída da rede. Os neurônios ocultos representam a interface entre as entradas e os neurônios visíveis representando a camada de saída da rede.

# %% [markdown]
# **Comentário da resposta:**
# Os neurônios da máquina de Boltzmann são divididos em dois grupos, os neurônios visíveis e os neurônios ocultos. Os neurônios visíveis representam a interface da máquina com o meio e funciona tanto como camada de entrada (recebimento dos dados) quanto camada de saída (geração dos dados). Os neurônios da camada oculta, por sua vez, especializam-se em padrões de correlação presentes nos dados de entrada e funcionam como extratores de características dos dados.

# %% [markdown]
# ## **Semana 7 - Atividade Avaliativa**

# %% [markdown]
# **PERGUNTA 1**
#
# Liste as principais diferenças entre as unidades GRU (Gated Recurrent Unit) e LSTM (Long Short-Term Memory):
#
# A GRU não permite a criação de uma arquitetura bidirecional. Esta só é possível com as unidades LSTM.
#
# **A GRU possui apenas uma variável de estado (sinal de memória) e 2 portas de controle, a LSTM possui duas variáveis de estado (sinal memória) e 3 portas.** 🧸
#
# A GRU e LSTM possuem a mesma quantidade de portas e variáveis de estado. A diferença principal está na forma de treinamento dos modelos.
#
# A GRU possui duas variáveis de estado (sinal de memória) e 2 portas, a LSTM possui apenas uma variável de estado (sinal memória) e 3 portas.
#
# A GRU e LSTM diferem no número de camadas utilizadas no modelo. A GRU possui apenas uma camada oculta e a LSTM possui duas camadas ocultas.

# %% [markdown]
# **Comentário da resposta:**
# As duas unidades são bastante parecidas, porém, a GRU pode ser vista como uma simplificação da LSTM. Especificamente, a GRU possui apenas um estado interno (sinal de memória) enquanto a LSTM possui dois. Em relação ao número de portas, a GRU possui uma ou duas portas em suas versões simplificada e completa, respectivamente, enquanto a LSTM possui três portas de controle. Ambas são treinadas da mesma forma, via algoritmo de retropropagação através do tempo e ambas permitem a criação de arquiteturas bidirecionais.

# %% [markdown]
# **PERGUNTA 2**
#
# Associe a arquitetura de rede recorrente abaixo a um possível problema que possa utilizá-la.
# 1. Muitos para um
# 2. Um para muitos
# 3. Muitos para muitos
#
# a. Transcrição de áudio em texto.
#
# b. Predição do valor futuro de uma ação.
#
# c. Geração automática de texto.
#
# 1-a; 2-b; 3-c.
#
# 1-a; 2-c; 3-b.
#
# 1-b; 2-a; 3-c.
#
# 1-c; 2-b; 3-a.
#
# **1-b; 2-c; 3-a.** 🌅

# %% [markdown]
# **Comentário da resposta:**
# Conforme apresentado no slide 9 da Videoaula 19, a arquitetura 1), muitos para um, recebe diversos padrões (instantes) para gerar um valor ao único ao final. Esse tipo de arquitetura pode ser usado para predição de valores em séries temporais, como no mercado de ações, análise de sentimentos, dentre outras tarefas. A arquitetura 2), um para muitos, recebe uma entrada e, a partir deste, gera uma sequência de saídas. Esse tipo de arquitetura é comumente aplicado para geração de sinais de texto e áudio. Por fim, a arquitetura 3), muitos para muitos, é usada quando para cada entrada no tempo temos a geração de um sinal de saída. Pode ser usada em diversas tarefas, como transcrição de áudio em texto, síntese de voz a partir de texto, classificação de palavras em uma sentença etc. Uma ilustração dessas arquiteturas e algumas de suas aplicações pode ser visualizada no link (em inglês): https://stanford.edu/~shervine/teaching/cs-230/cheatsheet-recurrent-neural-networks.

# %% [markdown]
# **PERGUNTA 3**
#
# Quais dos problemas abaixo são comumente abordados com redes neurais recorrentes?
#
# Classificação de imagens, agrupamento de dados e análise de sentimentos.
#
# Análise de sentimentos, classificação de imagens e criação memórias associativas.
#
# Classificação de imagens, agrupamento de dados e classificação binária.
#
# **Análise de sentimentos; reconhecimento de fala e tradução.** 🐑
#
# Classificação de imagens, aproximação de funções e criação de memórias associativas.

# %% [markdown]
# **Comentário da resposta:**
# Como ilustrado no slide 6 da Videoaula 19, diversos problemas podem ser resolvidos com redes neurais recorrentes, dente eles: reconhecimento de fala, geração de sinais (música, texto etc.), classificação (análise) de sentimentos, reconhecimento de cenas em vídeos, tradução etc. O material de apoio 3 desta semana (“A Matemática da Dissipação do Gradiente e Aplicações das RNNs”) também aborda algumas aplicações com redes neurais recorrentes.

# %% [markdown]
# **PERGUNTA 4**
#
# Qual é a função da porta de saída (gate de output) de uma rede LSTM?
#
# O gate de output é responsável pela atualização do sinal interno do neurônio, representado por ct.
#
# O gate de output, que consiste numa porta binária, é responsável por habilitar ou não a saída dos neurônios da camada LSTM.
#
# O gate de output é responsável por controlar a formação do estado candidato, representado por ct, gerado no tempo t que, posteriormente, irá compor a saída da rede.
#
# **O gate de output é responsável por indicar qual parte do sinal interno gerado, representado por ct, irá compor a saída da camada LSTM (representada por at).** 🐇
#
# O gate de output é responsável por indicar qual parte do sinal anterior, representado por at-1, irá compor a saída da camada LSTM (representada por at).

# %% [markdown]
# **Comentário da resposta:**
# O gate de output (porta de saída) é responsável pela formação da saída dos neurônios (camada LSTM). Basicamente, essa porta controla qual informação do estado interno (estado oculto) do neurônio, representado por ct, irá compor a saída visível da camada, representada por $a^t$.

# %% [markdown]
# **PERGUNTA 5**
#
# Qual é a função do truncamento no algoritmo de retropropagação através do tempo?
#
# **O truncamento possui duas funções principais: limitação do custo computacional e estabilidade numérica do cálculo do gradiente.** 🔥
#
# O truncamento funciona como uma regularização do modelo, evitando que os pesos se saturem.
#
# O truncamento possui como objetivo limitar o tamanho do vetor gradiente.
#
# O truncamento é responsável por interromper o processo de treinamento de forma antecipada, evitando o overfitting dos dados.
#
# O truncamento elimina o problema do desaparecimento ou explosão do vetor gradiente.

# %% [markdown]
# **Comentário da resposta:**
# O truncamento evita que a retropropagação no tempo retorne até o tempo zero. Com isso, reduz-se o custo computacional do treinamento e faz com que o modelo reduza a influência de longo prazo. Por limitar o número de iterações no tempo, o truncamento também reduz as chances de explosão ou desaparecimento do gradiente no treinamento das redes recorrentes.

# %% [markdown]
# **PERGUNTA 6**
#
# Qual das equações abaixo representa a formulação correta para o cálculo do estado do neurônio oculto (a) no tempo t?
#
# Um neurônio oculto representado por um círculo azul possui 2 entradas, X=[X1, X2]. Os pesos associados a cada uma destas entradas são Wx1 e Wx2, respectivamente. O neurônio em azul (oculto) possui uma realimentação cujo peso é Wa. O neurônio oculto representado em azul está interligado a outro neurônio (não oculto) representado em amarelo pela letra Y e seu respectivo peso Wy.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Obs.: x representa a entrada do neurônio x=[x1,x2], a representa o estado interno do neurônio oculto e y o sinal de saída. Os pesos associados a entrada são representados por wx=[wx1, wx2], os pesos associados à realimentação são representados por wa, por fim, o peso da unidade de saída é representado por wy. A unidade sobrescrita, i.e., t em xt representa o sinal no tempo t. Phi representa a função de ativação dos neurônios. Considere que o neurônio acima não possui o bias.

# %% [markdown]
# $𝛼^t=φ(𝜔_a 𝛼^{t-1} + 𝜔_xX+𝜔_yy)$

# %% [markdown]
# $𝛼^t=φ(𝜔_a 𝛼^{t-1}+𝜔_xX^t+𝜔_yy^t)$

# %% [markdown]
# $𝛼^t=φ(𝜔_a𝛼^t+𝜔_xX)$

# %% [markdown]
# $𝛼^t=φ(𝜔_a𝛼^{t-1}+𝜔_xX^t)$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $𝛼^t=φ(𝜔_a𝛼^{t-1}+𝜔_xX)$

# %% [markdown]
# **Comentário da resposta:**
# O cálculo do estado do neurônio no tempo $t$, representado por $a^t$, é definido pela soma dos produtos entre os pesos e sinais. Especificamente, a entrada $x^t$ é multiplicada pelo vetor de pesos $W_x$, o sinal do estado at-1 referente ao estado do neurônio no instante anterior é multiplicado pelo peso $W_a$.
